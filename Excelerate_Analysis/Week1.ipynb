# %%
import pandas as pd
cp = pd.read_excel('Dataset.xlsx')
cp.head()
# Out:
#   Learner SignUp DateTime                  Opportunity Id  \
# 0     06/14/2023 12:30:35  00000000-0GN2-A0AY-7XK8-C5FZPP
# 1     2023-01-05 05:29:16  00000000-0GN2-A0AY-7XK8-C5FZPP
# 2     2023-09-04 20:35:08  00000000-0GN2-A0AY-7XK8-C5FZPP
# 3     08/29/2023 05:20:03  00000000-0GN2-A0AY-7XK8-C5FZPP
# 4     2023-06-01 15:26:36  00000000-0GN2-A0AY-7XK8-C5FZPP
#
#                                     Opportunity Name Opportunity Category  \
# 0  Career Essentials: Getting Started with Your P...               Course
# 1  Career Essentials: Getting Started with Your P...               Course
# 2  Career Essentials: Getting Started with Your P...               Course
# 3  Career Essentials: Getting Started with Your P...               Course
# 4  Career Essentials: Getting Started with Your P...               Course
#
#   Opportunity End Date        First Name        Date of Birth  Gender  \
# 0  06/29/2024 18:52:39             Faria  2001-12-01 00:00:00  Female
# ...

# %% [markdown]
# - check the datatypes of each column

# %%
#Display the datatypes of each column in the dataframe
cp.dtypes
# Out:
# Learner SignUp DateTime            object
# Opportunity Id                     object
# Opportunity Name                   object
# Opportunity Category               object
# Opportunity End Date               object
# First Name                         object
# Date of Birth                      object
# Gender                             object
# Country                            object
# Institution Name                   object
# Current/Intended Major             object
# Entry created at           datetime64[ns]
# Status Description                 object
# Status Code                         int64
# Apply Date                         object
# Opportunity Start Date             object
# dtype: object

# %% [markdown]
# **Data Cleaning**

# %%
# Check data quality issues
print("Data Quality Issues:")
print(f"Missing values:\n{cp.isnull().sum()}")
print(f"\nDuplicate rows: {cp.duplicated().sum()}")

# Check for inconsistent categorical values
print(f"\nUnique values in categorical columns:")
categorical_cols = ['Gender', 'Country','Opportunity Category','Institution Name', 'Current/Intended Major', 'Status Description', 'Opportunity Name','Status Code']
for col in categorical_cols:
    if col in cp.columns:
        print(f"{col}: {cp[col].unique()}")
# Out:
# Data Quality Issues:
# Missing values:
# Learner SignUp DateTime       0
# Opportunity Id                0
# Opportunity Name              0
# Opportunity Category          0
# Opportunity End Date          0
# First Name                    0
# Date of Birth                 0
# Gender                        0
# Country                       0
# Institution Name              5
# Current/Intended Major        5
# Entry created at              0
# Status Description            0
# Status Code                   0
# Apply Date                    0
# Opportunity Start Date     3794
# dtype: int64
#
# Duplicate rows: 0
#
# Unique values in categorical columns:
# Gender: ['Female' 'Male' "Don't want to specify" 'Other']
# Country: ['Pakistan' 'India' 'United States' 'United Arab Emirates' 'Nigeria'
#  'Egypt' 'Nepal' 'Kenya' 'Ghana' 'Zambia' 'Morocco' 'Ethiopia' 'Zimbabwe'
#  'Uganda' 'Indonesia' 'Cameroon' 'Yemen' 'China' 'Bangladesh' 'Congo'
# ...

# %%
#inputting nan is some missing valus (handling missing data)
cp['Opportunity Start Date']=cp['Opportunity Start Date'].fillna('unknown')
#Drop rows with null values from the dataframe (handling missing data)
cp.dropna()
# Out:
#      Learner SignUp DateTime                  Opportunity Id  \
# 0        06/14/2023 12:30:35  00000000-0GN2-A0AY-7XK8-C5FZPP
# 1        2023-01-05 05:29:16  00000000-0GN2-A0AY-7XK8-C5FZPP
# 2        2023-09-04 20:35:08  00000000-0GN2-A0AY-7XK8-C5FZPP
# 3        08/29/2023 05:20:03  00000000-0GN2-A0AY-7XK8-C5FZPP
# 4        2023-06-01 15:26:36  00000000-0GN2-A0AY-7XK8-C5FZPP
# ...                      ...                             ...
# 8553     2024-05-03 16:39:21  00000000-10GQ-RJHT-3G4S-BKGBY1
# 8554     2024-06-03 15:58:47  00000000-10GQ-RJHT-3G4S-BKGBY1
# 8555     02/29/2024 15:02:31  00000000-10GQ-RJHT-3G4S-BKGBY1
# 8556     12/23/2023 03:53:12  00000000-10GQ-RJHT-3G4S-BKGBY1
# 8557     2023-01-06 13:22:01  00000000-10GQ-RJHT-3G4S-BKGBY1
#
#                                        Opportunity Name Opportunity Category  \
# 0     Career Essentials: Getting Started with Your P...               Course
# ...

# %%
# Drop rows with null values
cp_cleaned = cp.dropna()
# Save the cleaned data to a new Excel file
output_path = r"C:\Users\maruf\my Git\internship_week1\week1\SLU_Opportunity_Wise_Data_Cleaned_habiba.xlsx"

cp_cleaned.to_excel(output_path, index=False)

print(f"Cleaned file saved successfully at: {output_path}")
# Out:
# Cleaned file saved successfully at: C:\Users\maruf\my Git\internship_week1\week1\SLU_Opportunity_Wise_Data_Cleaned_habiba.xlsx

# %%
import pandas as pd

# Read Excel file but keep all columns as strings first
cp1 = pd.read_excel(r"C:\Users\maruf\my Git\internship_week1\week1\SLU_Opportunity_Wise_Data_Cleaned_habiba.xlsx", dtype=str)

""
# Convert only the true date columns to datetime
date_columns = [
    "Learner SignUp DateTime",
    "Opportunity End Date",
    "Date of Birth",
    "Entry created at",
    "Apply Date",
    "Opportunity Start Date"
]

for col in date_columns:
    cp1[col] = pd.to_datetime(cp1[col], format='mixed', errors='coerce')

cp1["Date of Birth"] = pd.to_datetime(cp1["Date of Birth"], format='mixed', errors='coerce').dt.date


print(cp1.dtypes)

#inputting nan is some missing valus (handling missing data)
cp1['Opportunity Start Date']=cp1['Opportunity Start Date'].fillna('unknown')

# Drop null rows and save cleaned file
cp_cleaned = cp1.dropna()
output_path = r"C:\Users\maruf\my Git\internship_week1\week1\SLU_Opportunity_Wise_Data_Cleaned_1.xlsx"

cp_cleaned.to_excel(output_path, index=False)

print(f"✅ Cleaned file saved successfully at: {output_path}")
print(cp_cleaned.shape)
# Out:
# Learner SignUp DateTime    datetime64[ns]
# Opportunity Id                     object
# Opportunity Name                   object
# Opportunity Category               object
# Opportunity End Date       datetime64[ns]
# First Name                         object
# Date of Birth                      object
# Gender                             object
# Country                            object
# Institution Name                   object
# Current/Intended Major             object
# Entry created at           datetime64[ns]
# Status Description                 object
# Status Code                        object
# Apply Date                 datetime64[ns]
# Opportunity Start Date     datetime64[ns]
# dtype: object
# ✅ Cleaned file saved successfully at: C:\Users\maruf\my Git\internship_week1\week1\SLU_Opportunity_Wise_Data_Cleaned_1.xlsx
# (6839, 16)

# %%
import pandas as pd

# Read Excel file but keep all columns as strings first
cp2 = pd.read_excel(r"C:\Users\maruf\my Git\internship_week1\week1\SLU_Opportunity_Wise_Data_Cleaned_1.xlsx", dtype=str)

#Handling Inconsistent country names based on unique vallues details:
cp2['Country'] = cp2['Country'].str.replace('U.S.', 'United States')
cp2['Country'] = cp2['Country'].str.replace('Iran, Islamic Republic of Persian Gulf', 'Iran')
cp2['Country'] = cp2['Country'].str.replace('Iran  Islamic Republic of Persian Gulf', 'Iran')

# Drop null rows and save cleaned file
cp_cleaned = cp2.dropna()

output_path = r"C:\Users\maruf\my Git\internship_week1\week1\SLU_Opportunity_Wise_Data_Cleaned_T1.xlsx"

cp_cleaned.to_excel(output_path, index=False)

print(f"✅ Cleaned file saved successfully at: {output_path}")
print(cp2.shape)
cp.head()
# Out:
# ✅ Cleaned file saved successfully at: C:\Users\maruf\my Git\internship_week1\week1\SLU_Opportunity_Wise_Data_Cleaned_T1.xlsx
# (6839, 16)
#   Learner SignUp DateTime                  Opportunity Id  \
# 0     2023-06-14 12:30:35  00000000-0GN2-A0AY-7XK8-C5FZPP
# 1     2023-01-05 05:29:16  00000000-0GN2-A0AY-7XK8-C5FZPP
# 2     2023-08-29 05:20:03  00000000-0GN2-A0AY-7XK8-C5FZPP
# 3     2023-06-01 15:26:36  00000000-0GN2-A0AY-7XK8-C5FZPP
# 4     2023-05-31 07:11:04  00000000-0GN2-A0AY-7XK8-C5FZPP
#
#                                     Opportunity Name Opportunity Category  \
# 0  Career Essentials: Getting Started with Your P...               Course
# 1  Career Essentials: Getting Started with Your P...               Course
# 2  Career Essentials: Getting Started with Your P...               Course
# 3  Career Essentials: Getting Started with Your P...               Course
# 4  Career Essentials: Getting Started with Your P...               Course
#
# ...
